# %% [markdown]
# ## Importing NBA Data

# %%
import requests as rq

# Specify the API endpoint URL
url = 'https://www.nba.com/standings'

# Define parameters for the request
params = {
    #'LeagueID': '00',
    #'PerMode': 'PerGame',
    #'Scope': 'RS',
    'Season': '2023-24',
    'Group By' : 'Conference',
    'Section' : 'Overall'
    #'SeasonType': 'Regular Season',
    #'StatCategory': 'PTS'
}

# Make a GET request to the API endpoint
response = rq.get(url, params=params)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    # Process the data further as needed
    print(data)
else:
    print('Error:', response.status_code)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# /opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#
# /opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-1-7ad6a5e8e213> in <module>
#      22 if response.status_code == 200:
#      23     # Parse the JSON response
# ---> 24     data = response.json()
#      25     # Process the data further as needed
#      26     print(data)
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     973             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     976
#     977     @property
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the website
url = "https://www.actionnetwork.com/nba/odds/boston-celtics"
url2 = "https://www.nba.com/standings"

# Send a GET request to the URL
response = requests.get(url2)

# Parse the HTML content
soup = BeautifulSoup(response.text, "html.parser")

print(response.text)
# # Find the table titled "Celtics 2024 Schedule & Betting Odds"
# table = soup.find("table", {"class": "css-1uek3nh epxndxd0"})

# # Extract table headers
# headers = [header.text.strip() for header in table.find_all("th")]

# # Extract table rows
# rows = []
# for row in table.find_all("tr"):
#     row_data = [data.text.strip() for data in row.find_all("td")]
#     if len(row_data) == len(headers):
#         rows.append(row_data)

# # Create a DataFrame
# pineapples = pd.DataFrame(rows, columns=headers)

# # Display the DataFrame
# print(pineapples)
# Out:
# <!DOCTYPE html><html lang="en" data-version="4.21.0" data-build="13091"><head><meta charSet="utf-8"/><link rel="manifest" href="/site-manifest.json"/><meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no"/><script src="/newrelic/newrelic-prod.js"></script><script id="theme-loader" src="/theme-loader.js"></script><title>NBA Team Standings &amp; Stats | NBA.com</title><meta name="description" content="The standings and stats of the current NBA season. Keep track of how your favorite teams are performing and who will make the playoffs."/><link rel="icon" href="/favicon.ico"/><link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png"/><link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png"/><link rel="apple-touch-icon" href="/apple-touch-icon.png"/><link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png"/><link rel="apple-touch-icon" sizes="120x120" href="/apple-touch-icon.png"/><link href="/apple-touch-icon.png"/><meta name="msapplication-TileColor" content="#da532c"/><link rel="mask-icon" href="/safari-pinned-tab.svg" color="#051c2d"/><meta name="next-head-count" content="16"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin /><link rel="preload" href="/_next/static/css/2ba3c19812a9afae.css" as="style"/><link rel="stylesheet" href="/_next/static/css/2ba3c19812a9afae.css" data-n-g=""/><link rel="preload" href="/_next/static/css/eac0ec4b93c75f24.css" as="style"/><link rel="stylesheet" href="/_next/static/css/eac0ec4b93c75f24.css" data-n-p=""/><link rel="preload" href="/_next/static/css/a6a2e846df1ab217.css" as="style"/><link rel="stylesheet" href="/_next/static/css/a6a2e846df1ab217.css" data-n-p=""/><link rel="preload" href="/_next/static/css/d086e5f37bb7e0ad.css" as="style"/><link rel="stylesheet" href="/_next/static/css/d086e5f37bb7e0ad.css" data-n-p=""/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js"></script><script src="/_next/static/chunks/webpack-ba3c9729ffdb42d8.js" defer=""></script><script src="/_next/static/chunks/framework-6a24ea55bfe2d3c0.js" defer=""></script><script src="/_next/static/chunks/main-878323283d90b24a.js" defer=""></script><script src="/_next/static/chunks/pages/_app-b2d60e1a83ffc110.js" defer=""></script><script src="/_next/static/chunks/45992-7c795df2ddc81afc.js" defer=""></script><script src="/_next/static/chunks/37559-97ec81efc387969e.js" defer=""></script><script src="/_next/static/chunks/38525-975fb919e21f6e34.js" defer=""></script><script src="/_next/static/chunks/95563-4c79902784e92575.js" defer=""></script><script src="/_next/static/chunks/68885-688a51442651b273.js" defer=""></script><script src="/_next/static/chunks/95727-3473c864e7a5cbd2.js" defer=""></script><script src="/_next/static/chunks/34179-514e799059d32e96.js" defer=""></script><script src="/_next/static/chunks/45789-bc0d6c021c111ac7.js" defer=""></script><script src="/_next/static/chunks/47218-9c882994b7ffc12e.js" defer=""></script><script src="/_next/static/chunks/77901-ad4ceda9b682fb44.js" defer=""></script><script src="/_next/static/chunks/55951-6a8cfee98dbd5110.js" defer=""></script><script src="/_next/static/chunks/pages/standings-ef82ea4a49a2943e.js" defer=""></script><script src="/_next/static/a-gqbFPSsp2sVKJusaGPN/_buildManifest.js" defer=""></script><script src="/_next/static/a-gqbFPSsp2sVKJusaGPN/_ssgManifest.js" defer=""></script><style data-href="https://fonts.googleapis.com/css?family=Roboto:300,400,700,900|Roboto+Condensed:400,700|Roboto+Slab:400,700&display=swap">@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmSU5fBBc-.woff) format('woff')}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v30/KFOmCnqEu92Fr1Mu4mxM.woff) format('woff')}@font-face{fo ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <script>
#       var _esi = {
#         country: "US",
#         tz: "EST",
#         region: "PA",
#         browser: "OTHER",
#         os: "OTHER",
#         device: "computer",
#         isMobile: "false",
#         isDomestic: "true",
#         ip: "128.180.223.32"
#       };
#     </script>
#
# </div></div><div class="Layout_base__6IeUC Layout_justNav__2H4H0" data-with-subnav-banner="false"><div class="Layout_fixedContent__kWFtM" data-has-draft-tracker="false"><div class="NavBar_wrapper__kwo09"><nav class="NavBar_nav__U9xyc" data-is-extra-height="false"><div class="NavBar_topGroupWrapper__Bb2Vc"><button class="NavHamburger_hamburger__kqDDP NavHamburger_squeeze__F9qaj" data-is-open="false" type="button" title="Global Navigation Toggle" data-track="click" data-type="icon" data-id="nba:navigation:menu-hamburger:icon" data-content="menu-hamburger"><span class="NavHamburger_box__r0p_S"><span class="NavHamburger_inner__whZdg"><span class="NavHamburger_navToggle__nOZPv">Navigation Toggle</span></span></span></button><a href="/" class="Anchor_anchor__cSc3P NavLogo_nl__b4Mct" data-is-external="false" data-has-more="false" data-has-children="true" data-track="click" data-type="logo" data-id="nba:navigation:home:logo" data-content="home" title="NBA Logo Homepage Button" data-large-icon="false"><img src="https://cdn.nba.com/logos/leagues/logo-nba.svg" alt="NBA Logo" title="NBA Logo"/><span class="sr-only">NBA</span></a><ul id="nav-ul" class="NavBar_menu__yO4Am" data-is-open="false"><li class="NavItem_item__Gokj_" data-dropdown="true" data-is-hidden="false" aria-haspopup="true" aria-expanded="false"><a href="/games" class="Anchor_anchor__cSc3P NavItem_link__ZBDtq" data-is-external="false" data-has-more="false" data-has-children="true" data-track="click" data-type="link" data-pos="1/18" data-id="nba:navigation:category:link" data-content="Games" data-text="Games" data-section="navbar"></a><div data-active="false" data-subnav="false" data-team="false" data-affil="false" class="NavDropdown_dropdown__HuIep"><ul class="NavDropdown_list__Phy7G"><li class="NavDropdownChild_item__k5Oea" data-is-drawer="false"><a href="/games" class="Anchor_anchor__cSc3P NavDropdownChild_link__NSYfR" data-is-external="false" data-has-more="false" data-has-children="true" data-link-enabled="true" title="" data-track="click" data-type="link" data-id="nba:navigation:subcategory:link" data-text="Home" data-content="Games" data-section="navbar">Home</a></li><li class="NavDropdownChild_item__k5Oea" data-is-drawer="false"><a href="https://nbatickets.nba.com/?cid=nba:tickets:institutional:nbacom:domsites:rd" class="Anchor_anchor__cSc3P NavDropdownChild_link__NSYfR" data-is-external="false" data-has-more="false" data-has-children="true" data-link-enabled="true" title="" data-track="click" data-type="link" data-id="nba:navigation:subcategory:link" data-text="Tickets" data-content="Games" data-section="navbar" rel="noopener noreferrer nofollow" target="_blank">Tickets</a></li></ul></div></li><li class="NavItem_item__Gokj_" data-dropdown="true" data-is-hidden="false" aria-haspopup="true" aria-expanded="false"><a href="/schedule" class="Anchor_anchor__cSc3P NavItem_link__ZBDtq" data-is-external="false" data-has-more="false" data-has-children="true" data-track="click" data-type="link" data-pos="2/18" data-id="nba:navigation:category:link" data-content="Schedule" data-text="Schedule" data-section="navbar"></a><div data-active="false" data-subnav="false" data-team="false" data-affil="false" class="NavDropdown_dropdown__HuIep"><ul class="NavDropdown_list__Phy7G"><li class="NavDropdownChild_item__k5Oea" data-is-drawer="false"><a href="/schedule" class="Anchor_anchor__cSc3P NavDropdownChild_link__NSYfR" data-is-external="false" data-has-more="false" data-has-children="true" data-link-enabled="true" title="" data-track="click" data-type="link" data-id="nba:navigation:subcategory:link" data-text="2023-24 Season Schedule" data-content="Schedule" data-section="navbar">2023-24 Season Schedule</a></li><li class="NavDropdownChild_item__k5Oea" data-is-drawer="false"><a href="/schedule?bc=LP&amp;cal=all&amp;region=1" class="Anchor_anchor__cSc3P NavDropdownChild_link__NSYfR" data-is-external="false" data-has-more="false" data-has-children="true" data-link-enabled="true" title="" data ...

# %%
import pandas as pd

# Specify the file path
file_path = "~/Desktop/Fin_377_Final_Data.xlsx"

# Read the Excel file into a DataFrame
data_frame = pd.read_excel(file_path)

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# Display the DataFrame=
data_frame
# Out:
#    Celtics 2024 Schedule & Betting Odds Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                   NaN        NaN        NaN        NaN
# 1                                  DATE   OPPONENT      SCORE     SPREAD
# 2                              Apr 14th        WAS          -          -
# 3                              Apr 12th        CHA          -          -
# 4                              Apr 11th        NYK  L 109-118     -3.5 L
# 5                               Apr 9th       @MIL   L 91-104     +3.5 L
# 6                               Apr 7th        POR  W 124-107      -17 L
# 7                               Apr 5th        SAC  W 101-100       -9 L
# 8                               Apr 3rd        OKC  W 135-100      -12 W
# 9                               Apr 1st       @CHA  W 118-104    -18.5 L
# 10                             Mar 30th       @NOP   W 104-92       -6 W
# 11                             Mar 28th       @ATL  L 122-123      -16 L
# 12                             Mar 25th       @ATL  L 118-120    -10.5 L
# 13                             Mar 23rd       @CHI  W 124-113       -5 W
# 14                             Mar 22nd       @DET  W 129-102    -13.5 W
# 15                             Mar 20th        MIL  W 122-119    -10.5 L
# 16                             Mar 18th        DET   W 119-94      -15 W
# 17                             Mar 17th       @WAS  W 130-104    -14.5 W
# 18                             Mar 14th        PHX  W 127-112     -5.5 W
# 19                             Mar 12th       @UTA  W 123-107     -6.5 W
# 20                             Mar 11th       @POR   W 121-99      -11 W
# 21                              Mar 9th       @PHX  W 117-107     -5.5 W
# 22                              Mar 7th       @DEN  L 109-115       -2 L
# 23                              Mar 5th       @CLE  L 104-105     -8.5 L
# 24                              Mar 3rd        GSW   W 140-88       -8 W
# 25                              Mar 1st        DAL  W 138-110     -8.5 W
# 26                             Feb 27th        PHI   W 117-99    -11.5 W
# 27                             Feb 24th       @NYK  W 116-102       -6 W
# 28                             Feb 22nd       @CHI  W 129-112     -8.5 W
# 29                             Feb 14th        BKN   W 136-86    -11.5 W
# 30                             Feb 13th       @BKN  W 118-110       -8 L
# 31                             Feb 11th       @MIA  W 110-106       -8 L
# 32                              Feb 9th        WAS  W 133-129      -18 L
# 33                              Feb 7th        ATL  W 125-117      -12 L
# 34                              Feb 4th        MEM   W 131-91    -19.5 W
# 35                              Feb 1st        LAL  L 105-114    -15.5 L
# 36                             Jan 30th        IND  W 129-124       -8 L
# 37                             Jan 29th        NOP  W 118-112       -8 L
# 38                             Jan 27th        LAC   L 96-115       -7 L
# 39                             Jan 25th       @MIA  W 140-110     -8.5 W
# 40                             Jan 22nd       @DAL  W 119-110     -2.5 W
# 41                             Jan 21st       @HOU  W 116-107    -11.5 L
# 42                             Jan 19th        DEN  L 100-102       -7 L
# 43                             Jan 17th        SAS   W 117-98    -14.5 W
# 44                             Jan 15th       @TOR   W 105-96     -6.5 W
# 45                             Jan 13th        HOU  W 145-113      -15 W
# 46                             Jan 11th       @MIL  L 102-135     +2.5 L
# 47                             Jan 10th        MIN  W 127-120    -10.5 L
# 48                              Jan 8th       @IND  L 131-133     -3.5 L
# 49                              Jan 6th       @IND  W 118-101       -7 W
# 50                              Jan 5th        UTA   W 126-97      -14 W
# 51                              Jan 2nd       @OKC  L 123-127       -4 L
# 52                             Dec 31st       @SAS  W 134-101    -14.5 W
# 53                             Dec 29th        TOR  W 120-118       -5 L
# 54                             Dec 28th        DET  W 128-122      -17 L
# 55                             Dec 25th       @LAL  W 126-115       -5 W
# 56                             Dec 23rd       @LAC  W 145-108     -4.5 W
# 57                             Dec 20th       @SAC  W 144-119     +3.5 W
# 58                             Dec 19th       @GSW  L 126-132       -5 L
# 59                             Dec 17th        ORL   W 114-97       -9 W
# 60                             Dec 15th        ORL  W 128-111     -5.5 W
# 61                             Dec 14th        CLE  W 116-107     -8.5 W
# 62                             Dec 12th        CLE  W 120-113    -11.5 L
# 63                              Dec 8th        NYK  W 133-123     -7.5 W
# 64                              Dec 4th       @IND  L 112-122     -4.5 L
# 65                              Dec 1st        PHI  W 125-119    -11.5 L
# 66                             Nov 28th        CHI   W 124-97    -12.5 W
# 67                             Nov 26th        ATL  W 113-103     -7.5 W
# 68                             Nov 24th       @ORL   L 96-113       -5 L
# 69                             Nov 22nd        MIL  W 119-116     -6.5 L
# 70                             Nov 20th       @CHA  L 118-121     -8.5 L
# 71                             Nov 19th       @MEM  W 102-100    -12.5 L
# 72                             Nov 17th       @TOR  W 108-105       -9 L
# 73                             Nov 15th       @PHI  W 117-107     -1.5 W
# 74                             Nov 13th        NYK   W 114-98     -9.5 W
# 75                             Nov 11th        TOR   W 117-94     -8.5 W
# 76                             Nov 10th        BKN  W 121-107      -12 W
# 77                              Nov 8th       @PHI  L 103-106     -2.5 L
# 78                              Nov 6th       @MIN  L 109-114     -3.5 L
# 79                              Nov 4th       @BKN  W 124-114      -10 L
# 80                              Nov 1st        IND  W 155-104    -13.5 W
# 81                             Oct 30th       @WAS  W 126-107    -10.5 W
# 82                             Oct 27th        MIA  W 119-111     -8.5 L
# 83                             Oct 25th       @NYK  W 108-104       -4 L
# 84                             Oct 19th       @CHA   W 127-99       -7 W
# 85                             Oct 17th        NYK  W 123-110      -10 W
# 86                             Oct 11th       @PHI  W 112-101     -2.5 W
# 87                              Oct 9th       @NYK  L 107-114     +8.5 W
# 88                              Oct 8th        PHI  W 114-106     -8.5 L
# 89                             Jul 15th       @ORL    W 94-77     -4.5 W
# 90                             Jul 14th       @NYK    L 89-97     -3.5 L
# 91                             Jul 12th        LAL    W 95-90     +3.5 W
# 92                              Jul 9th       @WAS   L 98-103     -3.5 L
# 93                              Jul 8th        MIA    L 88-99     -0.5 L
#
#     Unnamed: 4 Unnamed: 5
# 0          NaN        NaN
# 1   OVER/UNDER  MONEYLINE
# 2            -          -
# 3            -          -
# 4      O 221.5   NYK -155
# 5        U 231   MIL +142
# 6      O 216.5  BOS -1600
# 7        U 226   BOS -407
# 8        O 229   BOS -700
# 9      O 219.5  BOS -2149
# 10     U 223.5   BOS -230
# 11     O 228.5  ATL -1100
# 12       O 225   ATL -542
# 13       O 219   BOS -200
# 14       O 224   BOS -974
# 15       O 226   BOS -535
# 16       U 222  BOS -1350
# 17       O 226  BOS -1271
# 18       O 227   BOS -225
# 19       U 230   BOS -260
# 20       U 221   BOS -625
# 21       U 226   BOS -216
# 22       O 222   DEN -128
# 23       U 217   CLE -350
# 24       U 231   BOS -345
# 25     O 237.5   BOS -377
# 26     U 231.5   BOS -622
# 27     U 224.5   BOS -235
# 28       O 224   BOS -330
# 29       U 227   BOS -700
# 30       O 227   BOS -325
# 31       U 225   BOS -310
# 32     O 236.5  BOS -2500
# 33       U 244   BOS -700
# 34       O 219  BOS -2800
# 35     U 237.5  LAL -1450
# 36       O 249   BOS -350
# 37     U 233.5   BOS -310
# 38       U 232   LAC -260
# 39       O 225   BOS -335
# 40       U 241   BOS -140
# 41     U 226.5   BOS -675
# 42       U 234   DEN -275
# 43     U 237.5  BOS -1200
# 44     U 238.5   BOS -258
# 45     O 226.5  BOS -1100
# 46     U 247.5   MIL +110
# 47       O 228   BOS -500
# 48     O 246.5   IND -155
# 49       U 250   BOS -275
# 50     U 240.5  BOS -1100
# 51       O 240   OKC -174
# 52       U 241  BOS -1200
# 53     O 228.5   BOS -198
# 54       O 234  BOS -1400
# 55       O 235   BOS -198
# 56       O 231   BOS -178
# 57     O 238.5   BOS +140
# 58     O 233.5   GSW -200
# 59       U 226   BOS -355
# 60     O 227.5   BOS -212
# 61     U 227.5   BOS -377
# 62     O 226.5   BOS -560
# 63       O 221   BOS -310
# 64     U 244.5   IND -195
# 65       O 218   BOS -575
# 66     O 219.5   BOS -770
# 67       U 236   BOS -297
# 68       U 221   ORL -205
# 69     U 235.5   BOS -245
# 70       O 234   CHA -352
# 71     U 222.5   BOS -625
# 72       U 224   BOS -375
# 73     O 223.5   BOS -122
# 74     U 220.5   BOS -440
# 75       U 223   BOS -369
# 76       U 229   BOS -658
# 77     U 229.5   PHI -148
# 78       O 222   MIN -160
# 79     O 227.5   BOS -440
# 80     O 233.5   BOS -800
# 81     O 231.5   BOS -510
# 82     O 217.5   BOS -355
# 83       U 223   BOS -175
# 84       U 229   BOS -265
# 85       O 219   BOS -375
# 86     U 218.5   BOS -143
# 87       O 219   NYK +275
# 88       O 218   BOS -302
# 89       U 177   BOS -200
# 90     O 182.5   NYK -170
# 91     U 185.5   BOS +130
# 92     O 179.5   WAS -175
# 93     O 184.5   MIA -112
