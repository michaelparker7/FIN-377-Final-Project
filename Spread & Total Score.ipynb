# %% [markdown]
# ## Celtics

# %%
import pandas as pd

# Specify the file path
file_path = "~/Desktop/Fin_377_Final_Data.xlsx"

# Read the Excel file into a DataFrame
data_frame = pd.read_excel(file_path, sheet_name='Celtics')

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# Display the DataFrame=
data_frame
# Out:
#         DATE OPPONENT      SCORE   SPREAD OVER/UNDER  MONEYLINE
# 0    May 3rd     @MIA          -        -          -          -
# 1    May 1st      MIA          -        -          -          -
# 2   Apr 29th     @MIA          -        -          -          -
# 3   Apr 27th     @MIA   W 104-84   -9.5 W      U 205   BOS -440
# 4   Apr 24th      MIA  L 101-111  -14.5 L    O 205.5  MIA -1450
# 5   Apr 21st      MIA   W 114-94  -14.5 W    U 210.5  BOS -1175
# 6   Apr 14th      WAS  W 132-122    -10 L      O 229   BOS -452
# 7   Apr 12th      CHA   W 131-98   -7.5 W    O 217.5   BOS -305
# 8   Apr 11th      NYK  L 109-118   -3.5 L    O 221.5   NYK -155
# 9    Apr 9th     @MIL   L 91-104   +3.5 L      U 231   MIL +142
# 10   Apr 7th      POR  W 124-107    -17 L    O 216.5  BOS -1600
# 11   Apr 5th      SAC  W 101-100     -9 L      U 226   BOS -407
# 12   Apr 3rd      OKC  W 135-100    -12 W      O 229   BOS -700
# 13   Apr 1st     @CHA  W 118-104  -18.5 L    O 219.5  BOS -2149
# ...

# %% [markdown]
# ## Nuggets

# %%
import pandas as pd

# Specify the file path
file_path = "~/Desktop/Fin_377_Final_Data.xlsx"

# Read the Excel file into a DataFrame
data_frame = pd.read_excel(file_path, sheet_name='Nuggets')

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# Display the DataFrame=
data_frame
# Out:
#         DATE OPPONENT      SCORE   SPREAD OVER/UNDER  MONEYLINE
# 0    May 4th      LAL          -        -          -          -
# 1    May 2nd     @LAL          -        -          -          -
# 2   Apr 29th      LAL          -        -          -          -
# 3   Apr 27th     @LAL  L 108-119   -3.5 L    O 219.5   LAL -163
# 4   Apr 25th     @LAL  W 112-105   +1.5 W    U 217.5   DEN +102
# 5   Apr 22nd      LAL   W 101-99     -7 L      U 223   DEN -285
# 6   Apr 20th      LAL  W 114-103   -6.5 W      U 227   DEN -259
# 7   Apr 14th     @MEM  W 126-111  -13.5 W    O 216.5   DEN -900
# 8   Apr 12th     @SAS  L 120-121    -12 L      O 223   SAS -674
# 9   Apr 10th      MIN  W 116-107   -7.5 W    O 215.5   DEN -315
# 10   Apr 9th     @UTA   W 111-95  -15.5 W      U 224  DEN -1800
# 11   Apr 6th      ATL  W 142-110  -10.5 W      O 224   DEN -625
# 12   Apr 4th     @LAC  L 100-102   -3.5 L    U 220.5   LAC -154
# 13   Apr 2nd      SAS  W 110-105  -15.5 L    U 223.5  DEN -1475
# ...

# %% [markdown]
# ## Lakers

# %%
import pandas as pd

# Specify the file path
file_path = "~/Desktop/Fin_377_Final_Data.xlsx"

# Read the Excel file into a DataFrame
data_frame = pd.read_excel(file_path, sheet_name='Lakers')

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# Display the DataFrame=
data_frame
# Out:
#          DATE OPPONENT      SCORE   SPREAD OVER/UNDER  MONEYLINE
# 0     May 4th     @DEN          -        -          -          -
# 1     May 2nd      DEN          -        -          -          -
# 2    Apr 29th     @DEN          -        -          -          -
# 3    Apr 27th      DEN  W 119-108   +3.5 W    O 219.5   LAL +137
# 4    Apr 25th      DEN  L 105-112   -1.5 L    U 217.5   DEN -121
# 5    Apr 22nd     @DEN   L 99-101     +7 W      U 223   DEN +232
# 6    Apr 20th     @DEN  L 103-114   +6.5 L      U 227   DEN +210
# 7    Apr 16th     @NOP  W 110-106     +1 W    U 224.5   LAL -103
# 8    Apr 14th     @NOP  W 124-108   +1.5 W    O 231.5   LAL +100
# 9    Apr 12th     @MEM  W 123-120  -15.5 L      O 226  LAL -1248
# 10    Apr 9th      GSW  L 120-134     +2 L    O 235.5   GSW +110
# 11    Apr 7th      MIN  L 117-127     +2 L      O 218   MIN +114
# 12    Apr 6th      CLE   W 116-97     -5 W      U 230   LAL -201
# ...

# %% [markdown]
# ## 76ers

# %%
import pandas as pd

# Specify the file path
file_path = "~/Desktop/Fin_377_Final_Data.xlsx"

# Read the Excel file into a DataFrame
data_frame = pd.read_excel(file_path, sheet_name='76ers')

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# Display the DataFrame=
data_frame
# Out:
#          DATE OPPONENT      SCORE   SPREAD OVER/UNDER  MONEYLINE
# 0     May 4th     @NYK          -        -          -          -
# 1     May 2nd      NYK          -        -          -          -
# 2    Apr 30th     @NYK          -        -          -          -
# 3    Apr 28th      NYK    L 92-97   -5.5 L      U 209   NYK -205
# 4    Apr 25th      NYK  W 125-114   -5.5 W    O 204.5   PHI -234
# 5    Apr 22nd     @NYK  L 101-104   +4.5 W      U 206   NYK +154
# 6    Apr 20th     @NYK  L 104-111   +4.5 L    O 208.5   NYK +153
# 7    Apr 17th      MIA  W 105-104   -5.5 L      O 208   PHI -225
# 8    Apr 14th      BKN   W 107-86    -13 W      U 215   PHI -774
# 9    Apr 12th      ORL  W 125-113   -6.5 W      O 215   PHI -258
# 10    Apr 9th      DET  W 120-102  -15.5 W    O 220.5  PHI -1350
# 11    Apr 7th     @SAS  W 133-126     -4 W      O 226   PHI -168
# 12    Apr 6th     @MEM   W 116-96  -14.5 W      U 214  PHI -1124
# ...

# %% [markdown]
# ## Wizards

# %%
import pandas as pd

# Specify the file path
file_path = "~/Desktop/Fin_377_Final_Data.xlsx"

# Read the Excel file into a DataFrame
data_frame = pd.read_excel(file_path, sheet_name='Wizards')

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# Display the DataFrame=
data_frame
# Out:
#         DATE OPPONENT      SCORE   SPREAD OVER/UNDER  MONEYLINE
# 0   Apr 14th     @BOS  L 122-132    +10 L      O 229   BOS +350
# 1   Apr 12th      CHI  L 127-129   -1.5 L    O 224.5   CHI -125
# 2    Apr 9th     @MIN  L 121-130    +18 W      O 223  MIN +1100
# 3    Apr 7th     @TOR  L 122-130     +5 L      O 235   TOR +157
# 4    Apr 5th      POR  L 102-108     -3 L      U 225   POR -142
# 5    Apr 3rd      LAL  L 120-125    +13 W      O 237   LAL +562
# 6    Apr 2nd      MIL  W 117-113    +13 W    O 225.5   WAS +625
# 7   Mar 31st      MIA  L 107-119    +12 L      O 214   MIA +495
# 8   Mar 29th      DET    L 87-96   -3.5 L    U 229.5   DET -154
# 9   Mar 27th      BKN  L 119-122     +4 W    O 220.5   BKN +142
# 10  Mar 25th     @CHI  W 107-105    +13 W    U 226.5   WAS +550
# 11  Mar 23rd      TOR  W 112-109     -6 L    U 232.5   WAS -230
# 12  Mar 21st      SAC  W 109-102    +11 W    U 238.5   WAS +452
# 13  Mar 19th      HOU  L 114-137    +10 L      O 228   HOU +382
# ...

# %% [markdown]
# ## Jazz

# %%
import pandas as pd

# Specify the file path
file_path = "~/Desktop/Fin_377_Final_Data.xlsx"

# Read the Excel file into a DataFrame
data_frame = pd.read_excel(file_path, sheet_name='Jazz')

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# Display the DataFrame=
data_frame
# Out:
#         DATE OPPONENT      SCORE   SPREAD OVER/UNDER MONEYLINE
# 0   Apr 14th     @GSW  L 116-123    +11 W    O 224.5  GSW +410
# 1   Apr 12th     @LAC  W 110-109    +16 W      U 225  UTA +850
# 2   Apr 11th      HOU  W 124-121    +11 W      O 227  UTA +395
# 3    Apr 9th      DEN   L 95-111  +15.5 L      U 224  DEN +990
# 4    Apr 7th     @GSW  L 110-118    +13 W    O 225.5  GSW +550
# 5    Apr 5th     @LAC  L 102-131  +12.5 L    O 224.5  LAC +550
# 6    Apr 2nd      CLE  L 113-129   +9.5 L      O 218  CLE +360
# 7   Mar 31st     @SAC  L 106-127    +13 L    O 220.5  SAC +625
# 8   Mar 29th      HOU  L 100-101   +8.5 W      U 230  HOU +262
# 9   Mar 27th      SAS  L 111-118     -4 L      O 228  SAS -170
# 10  Mar 25th      DAL  L 105-115     +8 L    U 238.5  DAL +270
# 11  Mar 23rd     @HOU  L 119-147  +10.5 L    O 227.5  HOU +395
# 12  Mar 21st     @DAL   L 97-113  +14.5 L    U 236.5  DAL +687
# 13  Mar 20th     @OKC  L 107-119  +15.5 W      U 232  OKC +824
# ...
